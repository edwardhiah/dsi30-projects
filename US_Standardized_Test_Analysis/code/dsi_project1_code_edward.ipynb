# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Being part of the College Board, To find out the states that are having low participation rate to provide more support to improve it.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*
# 1. SAT ACT Score Convertom Tables. ([source](https://www.crimsoneducation.org/sg/blog/test-prep/sat-vs-act-whats-the-difference/))
# 2. Which States Require the SAT? Complete List. ([source](https://blog.prepscholar.com/which-states-require-the-sat))
# 3. Which States Require the ACT? Full List and Advice. ([source](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def get_mean(list_of_numbers):
    return sum(list_of_numbers) / len(list_of_numbers)

# %%
#testing of the code: 
list_of_numbers = [1,2,3,4]
get_mean(list_of_numbers)
# Out:
# 2.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def get_std_dev(list_of_nums):
    
    num = len(list_of_nums)
    mean = sum(list_of_nums) / num
    var = sum((x - mean)**2 for x in list_of_nums) / num
    std_dev = var ** 0.5
    return std_dev

# %%
# create a list of data points
list_of_nums = [7, 2, 4, 3, 9, 12, 10, 2]
get_std_dev(list_of_nums)
# Out:
# 3.6550478793033614

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def convert_per_to_float(x):
    if type(x) != float and '%' in x:
        return float(x.strip('%'))/100
    else:
        return x

# %%
convert_per_to_float('5%')
# Out:
# 0.05

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display_html

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')

# %%
#Display the data: print the first 5 rows for sat_2017 data
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
#Display the data: print the first 5 rows for sat_2018 data
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#Display the data: print the first 5 rows for sat_2019 data
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#Check for missing values in dataframe.
dlist = {'sat_2017':sat_2017, 'sat_2018':sat_2018,'sat_2019':sat_2019,'act_2017':act_2017,'act_2018':act_2018,'act_2019':act_2019}
    
for key,value in dlist.items():
    print(f'\nCheck for missing values for dataframe {key} \
       \n------------------------------------------------'
    )
    display(value.isnull().sum())
# Out:
# Check for missing values for dataframe sat_2017
# ------------------------------------------------
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# Check for missing values for dataframe sat_2018
# ------------------------------------------------
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# Check for missing values for dataframe sat_2019
# ------------------------------------------------
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64
# Check for missing values for dataframe act_2017
# ------------------------------------------------
# ...

# %%
for key,value in dlist.items():
    print(f'\nCheck for concise summary for dataframe {key} \
       \n------------------------------------------------'
    )
    display (value.info()) 

    print(f'\nCheck for descriptive statistics for dataframe {key} \
       \n------------------------------------------------'
    )
    display (value.describe())
    print(f'\n------------------  End of {key} dataframe data info  ------------------\n\n')
# Out:
# Check for concise summary for dataframe sat_2017
# ------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
# Check for descriptive statistics for dataframe sat_2017
# ------------------------------------------------
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# ...

# %% [markdown]
# ### My findings on the 6 dataframe (sat_2017,2018,2019 & act_2017,act_2018,act_2019) :
# 1. There are no empty value for the six data frames.
# 2. Data frame header
#     -  i. sat_2019's header is different from the rest of the 5 data frames (should be Participation instead of Participation Rate)
#     - ii. sat_2017, sat_2018's Evidence-Based Reading and Writing header to change to be the same as sat_2019 (EBRW)
# 3. Data type
#     -   i. Participation data type is an object, should be float (% in cells)
#     -  ii. sat_2019's Participation is still object after % is removed. (due to wrong data in Perto Rico & Virgin Islands s' cell)
#     - iii. act_2017's Composite data type is currently an object, should be float (due to typo in Wyoming's composite cell)
# 4. Data values
#     -  i. Descriptive statistics for dataframe sat_2017 shows that min value of the Subject Math is lower then the min score of 200.
#     - ii. Descriptive statistics for dataframe act_2017 shows that min value of the Subject Science might be a outlier.
#    - iii. Typo error in the state name District of columbia for data frame act_2018

# %%
# change header for sat_2019 from 'Participation Rate'to 'Participation'
new_columns_dict = {
    'Participation Rate': 'Participation'
}
sat_2019.rename(columns=new_columns_dict, inplace=True)

# %%
# change header for sat_2017,sat_2018 from 'Evidence-Based Reading and Writing' to 'EBRW'
new_columns_dict = {
    'Evidence-Based Reading and Writing': 'EBRW'
}
sat_2017.rename(columns=new_columns_dict, inplace=True)
sat_2018.rename(columns=new_columns_dict, inplace=True)

# %%
# convert ['Participation'] values to float for all 6 dataframe (sat_2017,2018,2019 & act_2017,act_2018,act_2019)
for key,value in dlist.items():
    value['Participation'] = value['Participation'].map(convert_per_to_float)
value['Participation'].dtype
# Out:
# dtype('float64')

# %%
# filter to find what is not numeric in the column participation
sat_2019[pd.to_numeric(sat_2019.Participation, errors='coerce').isnull()]
# Out:
#              State Participation  EBRW  Math  Total
# 39     Puerto Rico             —   483   462    944
# 47  Virgin Islands             —   490   445    935

# %%
# to replace cells that is non-numberic to NaN
sat_2019['Participation'] = pd.to_numeric(sat_2019['Participation'], errors='coerce')

# %%
#filter to find what is not numeric in the column composite
act_2017[pd.to_numeric(act_2017.Composite, errors='coerce').isnull()]
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 51  Wyoming            1.0     19.4  19.8     20.8     20.6     20.2x

# %%
#found the correct data for the above error value thur the source https://nces.ed.gov/programs/digest/d17/tables/dt17_226.60.asp

#replace the typo in the cell
act_2017.loc[51, 'Composite'] = act_2017.loc[51, 'Composite'].strip('x')      #remove the typo x
act_2017['Composite'] = pd.to_numeric(act_2017['Composite'], errors='coerce') #convert data to float
print (act_2017.loc[51, 'Composite'])
# Out:
# 20.2

# %%
# check, SAT Score for Math should not be less then 200
sat_2017[sat_2017['Math'] <200]
# Out:
#        State  Participation  EBRW  Math  Total
# 20  Maryland           0.69   536    52   1060

# %%
#found the correct data for the above error value thur the source https://reports.collegeboard.org/media/pdf/2017-maryland-sat-suite-of-assessments-annual-report.pdf
#update the date with the correct value.
sat_2017.loc[20, 'Math'] = 524
sat_2017['Math'][20]
# Out:
# 524

# %%
# check for the outliner in the subject science
act_2017[act_2017['Science'] <19]
# Out:
#              State  Participation  English  Math  Reading  Science  Composite
# 21        Maryland           0.28     23.3  23.1     24.2      2.3       23.6
# 25     Mississippi           1.00     18.2  18.1     18.8     18.8       18.6
# 29          Nevada           1.00     16.3  18.0     18.1     18.2       17.8
# 41  South Carolina           1.00     17.5  18.6     19.1     18.9       18.7

# %%
#found the correct data for the above error value thur the source https://nces.ed.gov/programs/digest/d17/tables/dt17_226.60.asp
#update the date with the correct value.
act_2017.loc[21, 'Science'] = 23.2
act_2017['Science'][21]
# Out:
# 23.2

# %%
#Typo error in the state name District of columbia for data frame act_2018
act_2018.loc[8,'State']= 'District of Columbia'
act_2018['State'][8]
# Out:
# 'District of Columbia'

# %%
#Rename Columns.
#Column names should be all lowercase.

for key,value in dlist.items():
    value.columns = value.columns.str.lower()

# %%
# drop unwanted columns in act_2007 data frame
act_2017.head()
act_2017.drop(['english','math','reading','science'], axis=1).head()
# Out:
#       state  participation  composite
# 0  National           0.60       21.0
# 1   Alabama           1.00       19.2
# 2    Alaska           0.65       19.8
# 3   Arizona           0.62       19.7
# 4  Arkansas           1.00       19.4

# %%
#Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name']).
#Column names should be unique and informative.
# for key,value in dlist.items():
#     value.columns = value.columns+ '_'+ key
for key,value in dlist.items():
    for col in value:
        if col != 'state':
            value.rename(
                columns = {col : key[:3] + "_" + col + "_" + key[-4:]} 
                ,inplace=True)

# %%
act_2017.loc[(act_2017.state == 'National')]
# Out:
#       state  act_participation_2017  act_english_2017  act_math_2017  \
# 0  National                     0.6              20.3           20.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              21.4              21.0                21.0

# %%
act_2019.loc[(act_2019.state == 'National')]
# Out:
#        state  act_participation_2019  act_composite_2019
# 51  National                    0.52                20.7

# %%
#Combined the three years of SAT data frames together
combined_sat = sat_2017.merge(sat_2018, on='state',how ='outer').merge(sat_2019, on='state',how ='outer')
combined_sat.head()
# Out:
#         state  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                    0.05          593.0          572.0
# 1      Alaska                    0.38          547.0          533.0
# 2     Arizona                    0.30          563.0          553.0
# 3    Arkansas                    0.03          614.0          594.0
# 4  California                    0.53          531.0          524.0
#
#    sat_total_2017  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 0          1165.0                    0.06          595.0          571.0
# 1          1080.0                    0.43          562.0          544.0
# 2          1116.0                    0.29          577.0          572.0
# 3          1208.0                    0.05          592.0          576.0
# 4          1055.0                    0.60          540.0          536.0
#
#    sat_total_2018  sat_participation_2019  sat_ebrw_2019  sat_math_2019  \
# ...

# %%
#Combined the three years of ACT data frames together
combined_act = act_2017.merge(act_2018, on='state',how ='outer').merge(act_2019, on='state',how ='outer').drop(['act_english_2017','act_math_2017','act_reading_2017','act_science_2017'], axis=1)
combined_act.head()
# Out:
#       state  act_participation_2017  act_composite_2017  \
# 0  National                    0.60                21.0
# 1   Alabama                    1.00                19.2
# 2    Alaska                    0.65                19.8
# 3   Arizona                    0.62                19.7
# 4  Arkansas                    1.00                19.4
#
#    act_participation_2018  act_composite_2018  act_participation_2019  \
# 0                     NaN                 NaN                    0.52
# 1                    1.00                19.1                    1.00
# 2                    0.33                20.8                    0.38
# 3                    0.66                19.2                    0.73
# 4                    1.00                19.4                    1.00
#
#    act_composite_2019
# 0                20.7
# 1                18.9
# 2                20.1
# 3                19.0
# 4                19.3

# %%
#Combined the three years of ACT and three years of SAT data frames together
combined_standard_test = combined_sat.merge(combined_act, on='state')
combined_standard_test.head()
# Out:
#         state  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                    0.05          593.0          572.0
# 1      Alaska                    0.38          547.0          533.0
# 2     Arizona                    0.30          563.0          553.0
# 3    Arkansas                    0.03          614.0          594.0
# 4  California                    0.53          531.0          524.0
#
#    sat_total_2017  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 0          1165.0                    0.06          595.0          571.0
# 1          1080.0                    0.43          562.0          544.0
# 2          1116.0                    0.29          577.0          572.0
# 3          1208.0                    0.05          592.0          576.0
# 4          1055.0                    0.60          540.0          536.0
#
#    sat_total_2018  sat_participation_2019  sat_ebrw_2019  sat_math_2019  \
# ...

# %%
#Data Check on combined data frame
combined_standard_test.describe()
# Out:
#        sat_participation_2017  sat_ebrw_2017  sat_math_2017  sat_total_2017  \
# count               52.000000      52.000000      52.000000       52.000000
# mean                 0.408654     568.038462     555.769231     1123.903846
# std                  0.357579      45.881758      47.342563       92.940263
# min                  0.020000     482.000000     468.000000      950.000000
# 25%                  0.040000     531.750000     522.500000     1054.250000
# 50%                  0.405000     558.500000     544.500000     1104.500000
# 75%                  0.675000     612.500000     597.000000     1210.000000
# max                  1.000000     644.000000     651.000000     1295.000000
#
#        sat_participation_2018  sat_ebrw_2018  sat_math_2018  sat_total_2018  \
# count               52.000000      52.000000      52.000000       52.000000
# mean                 0.467692     562.692308     555.173077     1117.961538
# ...

# %%
combined_standard_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   52 non-null     object
#  1   sat_participation_2017  52 non-null     float64
#  2   sat_ebrw_2017           52 non-null     float64
#  3   sat_math_2017           52 non-null     float64
#  4   sat_total_2017          52 non-null     float64
#  5   sat_participation_2018  52 non-null     float64
#  6   sat_ebrw_2018           52 non-null     float64
#  7   sat_math_2018           52 non-null     float64
#  8   sat_total_2018          52 non-null     float64
#  9   sat_participation_2019  52 non-null     float64
#  10  sat_ebrw_2019           52 non-null     int64
#  11  sat_math_2019           52 non-null     int64
#  12  sat_total_2019          52 non-null     int64
#  13  act_participation_2017  52 non-null     float64
# ...

# %%
#Convert sat_total_2017,sat_total_2018 into int64
combined_standard_test.sat_total_2017 = combined_standard_test.sat_total_2017.astype(np.int64)
combined_standard_test.sat_total_2018 = combined_standard_test.sat_total_2018.astype(np.int64)

# %%
#check for duplicate rows in dataframe
combined_standard_test[combined_standard_test.duplicated()]
# Out:
#     state  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 20  Maine                    0.95          513.0          499.0
#
#     sat_total_2017  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 20            1012                    0.99          512.0          501.0
#
#     sat_total_2018  sat_participation_2019  sat_ebrw_2019  sat_math_2019  \
# 20            1013                    0.99            512            502
#
#     sat_total_2019  act_participation_2017  act_composite_2017  \
# 20            1013                    0.08                24.3
#
#     act_participation_2018  act_composite_2018  act_participation_2019  \
# 20                    0.07                24.0                    0.06
#
#     act_composite_2019
# 20                24.3

# %%
#Drop the duplicates and put into a new data frames 
combined_final = combined_standard_test.drop_duplicates()

# %%
#run the data frame head
combined_final.head()
# Out:
#         state  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                    0.05          593.0          572.0
# 1      Alaska                    0.38          547.0          533.0
# 2     Arizona                    0.30          563.0          553.0
# 3    Arkansas                    0.03          614.0          594.0
# 4  California                    0.53          531.0          524.0
#
#    sat_total_2017  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 0            1165                    0.06          595.0          571.0
# 1            1080                    0.43          562.0          544.0
# 2            1116                    0.29          577.0          572.0
# 3            1208                    0.05          592.0          576.0
# 4            1055                    0.60          540.0          536.0
#
#    sat_total_2018  sat_participation_2019  sat_ebrw_2019  sat_math_2019  \
# ...

# %%
#run the data frame tail
combined_final.tail()
# Out:
#             state  sat_participation_2017  sat_ebrw_2017  sat_math_2017  \
# 47       Virginia                    0.65          561.0          541.0
# 48     Washington                    0.64          541.0          534.0
# 49  West Virginia                    0.14          558.0          528.0
# 50      Wisconsin                    0.03          642.0          649.0
# 51        Wyoming                    0.03          626.0          604.0
#
#     sat_total_2017  sat_participation_2018  sat_ebrw_2018  sat_math_2018  \
# 47            1102                    0.68          567.0          550.0
# 48            1075                    0.69          543.0          538.0
# 49            1086                    0.28          513.0          486.0
# 50            1291                    0.03          641.0          653.0
# 51            1230                    0.03          633.0          625.0
#
#     sat_total_2018  sat_participation_2019  sat_ebrw_2019  sat_math_2019  \
# ...

# %%
#Save your cleaned and merged dataframes as csv files.
combined_final.to_csv('../data/combined_final.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |act_composite_2017|float|combined_final|ACT 2017 mean composite score|
# |act_composite_2018|float|combined_final|ACT 2018 mean composite score|
# |act_composite_2019|float|combined_final|ACT 2019 mean composite score|
# |act_participation_2017|float|combined_final|ACT 2017 participation rate in decimal|
# |act_participation_2018|float|combined_final|ACT 2018 participation rate in decimal|
# |act_participation_2019|float|combined_final|ACT 2019 participation rate in decimal|
# |sat_ebrw_2017|int|combined_final|SAT 2017 average Reading and Writing test score|
# |sat_ebrw_2018|int|combined_final|SAT 2018 average Reading and Writing test score|
# |sat_ebrw_2019|int|combined_final|SAT 2019 average Reading and Writing test score|
# |sat_math_2017|int|combined_final|SAT 2017 average Math test score|
# |sat_math_2018|int|combined_final|SAT 2018 average Math test score|
# |sat_math_2019|int|combined_final|SAT 2019 average Math test score|
# |sat_participation_2017|float|combined_final|SAT 2017 participation rate in decimal|
# |sat_participation_2018|float|combined_final|SAT 2018 participation rate in decimal|
# |sat_participation_2019|float|combined_final|SAT 2019 participation rate in decimal|
# |sat_total_2017|int|combined_final|SAT 2017 mean total score|
# |sat_total_2018|int|combined_final|SAT 2018 mean total score|
# |sat_total_2019|int|combined_final|SAT 2019 mean total score|
# |sat_diff_17_18|float|combined_final|SAT 2017_18 mean total score differences|
# |sat_diff_18_19|float|combined_final|SAT 2018_19 mean total score differences|
# |act_diff_17_18|float|combined_final|ACT 2017_18 mean composite score differences|
# |act_diff_18_19|float|combined_final|ACT 2018_19 mean composite score differences|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Summary Statistics
combined_final.describe().sort_index(axis=1).T
# Out:
#                         count         mean        std     min       25%  \
# act_composite_2017       51.0    21.519608   2.020695   17.80    19.800
# act_composite_2018       51.0    21.496078   2.111583   17.70    19.950
# act_composite_2019       51.0    21.464706   2.194523   17.90    19.800
# act_participation_2017   51.0     0.652549   0.321408    0.08     0.310
# act_participation_2018   51.0     0.617255   0.340371    0.07     0.285
# act_participation_2019   51.0     0.586667   0.345159    0.06     0.245
# sat_ebrw_2017            51.0   569.117647  45.666901  482.00   533.500
# sat_ebrw_2018            51.0   563.686275  47.502627  480.00   534.500
# sat_ebrw_2019            51.0   560.803922  46.248035  483.00   527.500
# sat_math_2017            51.0   556.882353  47.121395  468.00   523.500
# sat_math_2018            51.0   556.235294  47.772623  480.00   522.500
# sat_math_2019            51.0   552.196078  51.290553  460.00   511.500
# ...

# %% [markdown]
# ##### Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.

# %%
#output of the standard deviation of each numeric columns
std_dev_dict = {key: get_std_dev(value) for key, value in combined_final.iteritems() if key != 'state'}
std_dev_dict
# Out:
# {'sat_participation_2017': 0.3492907076664507,
#  'sat_ebrw_2017': 45.21697020437866,
#  'sat_math_2017': 46.65713364485503,
#  'sat_total_2017': 91.58351056778743,
#  'sat_participation_2018': 0.3694661922353942,
#  'sat_ebrw_2018': 47.03460978357609,
#  'sat_math_2018': 47.30194550378352,
#  'sat_total_2018': 93.22742384464433,
#  'sat_participation_2019': 0.3836584048685726,
#  'sat_ebrw_2019': 45.792378682545134,
#  'sat_math_2019': 50.78521461840036,
#  'sat_total_2019': 96.24027185617864,
#  'act_participation_2017': 0.3182417575123181,
#  'act_composite_2017': 2.000786081581989,
#  'act_participation_2018': 0.33701735820410317,
#  'act_composite_2018': 2.090779082141178,
#  'act_participation_2019': 0.3417582373703047,
#  'act_composite_2019': 2.172901153595978}

# %% [markdown]
# ### 3. Investigate trends in the data.

# %%
# Using sorting and/or masking (along with the .head() method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
# Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?
# Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT and ACT?
# Do any states with 100% participation on a given test have a rate change year-to-year?
# Do any states show have >50% participation on both tests each year?

# %% [markdown]
# ##### Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?

# %%
#Display states of highest SAT participation Rate for 2017, 2018, 2019

df1 = combined_final[combined_final['sat_participation_2017'] == combined_final['sat_participation_2017'].max()][['state','sat_participation_2017']]
df2 = combined_final[combined_final['sat_participation_2018'] == combined_final['sat_participation_2018'].max()][['state','sat_participation_2018']]
df3 = combined_final[combined_final['sat_participation_2019'] == combined_final['sat_participation_2019'].max()][['state','sat_participation_2019']]

df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Highest SAT participation rate for 2017')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Highest SAT participation rate for 2018')
df3_styler = df3.style.set_table_attributes("style='display:inline'").set_caption('Highest SAT participation rate for 2019')

space = "\xa0" * 20
display_html(df1_styler._repr_html_()+ space  + df2_styler._repr_html_()+ space  + df3_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d817a_" style='display:inline'>
#   <caption>Highest SAT participation rate for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_participation_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d817a_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_d817a_row0_col0" class="data row0 col0" >Connecticut</td>
#       <td id="T_d817a_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d817a_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_d817a_row1_col0" class="data row1 col0" >Delaware</td>
#       <td id="T_d817a_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d817a_level0_row2" class="row_heading level0 row2" >8</th>
# ...

# %% [markdown]
# ###### Findings :
#     - More states have acheived higher participating rate.
#     - Flordia SAT participation rate was 100% even though the state was not in the mandatory list to take SAT.
#     - New Hampshire particaption rate did not achieve 100% even thought the state was in the mandatory list to take SAT.

# %%
#Display states of highest ACT participation Rate for 2017, 2018, 2019

df4 = combined_final[combined_final['act_participation_2017'] == combined_final['act_participation_2017'].max()][['state','act_participation_2017']]
df5 = combined_final[combined_final['act_participation_2018'] == combined_final['act_participation_2018'].max()][['state','act_participation_2018']]
df6 = combined_final[combined_final['act_participation_2019'] == combined_final['act_participation_2019'].max()][['state','act_participation_2019']]

df4_styler = df4.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2017')
df5_styler = df5.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2018')
df6_styler = df6.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2019')

space = "\xa0" * 20
display_html(df4_styler._repr_html_()+ space  + df5_styler._repr_html_()+ space  + df6_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0baf_" style='display:inline'>
#   <caption>Highest ACT participation rate for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_participation_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0baf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0baf_row0_col0" class="data row0 col0" >Alabama</td>
#       <td id="T_c0baf_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0baf_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_c0baf_row1_col0" class="data row1 col0" >Arkansas</td>
#       <td id="T_c0baf_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0baf_level0_row2" class="row_heading level0 row2" >5</th>
# ...

# %% [markdown]
# ###### Findings :
#     - Number of state that acheive 100% participation rate decreased.
#     - Arkansas ACT participation rate was 100% even though the state was not in the mandatory list to take ACT.

# %%
#Display states of lowest SAT participation Rate for 2017, 2018, 2019

df7 = combined_final[combined_final['sat_participation_2017'] == combined_final['sat_participation_2017'].min()][['state','sat_participation_2017']]
df8 = combined_final[combined_final['sat_participation_2018'] == combined_final['sat_participation_2018'].min()][['state','sat_participation_2018']]
df9 = combined_final[combined_final['sat_participation_2019'] == combined_final['sat_participation_2019'].min()][['state','sat_participation_2019']]

df7_styler = df7.style.set_table_attributes("style='display:inline'").set_caption('Lowest SAT participation rate for 2017')
df8_styler = df8.style.set_table_attributes("style='display:inline'").set_caption('Lowest SAT participation rate for 2018')
df9_styler = df9.style.set_table_attributes("style='display:inline'").set_caption('Lowest SAT participation rate for 2019')

space = "\xa0" * 20
display_html(df7_styler._repr_html_()+ space  + df8_styler._repr_html_()+ space  + df9_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_070cb_" style='display:inline'>
#   <caption>Lowest SAT participation rate for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_participation_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_070cb_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_070cb_row0_col0" class="data row0 col0" >Iowa</td>
#       <td id="T_070cb_row0_col1" class="data row0 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_070cb_level0_row1" class="row_heading level0 row1" >25</th>
#       <td id="T_070cb_row1_col0" class="data row1 col0" >Mississippi</td>
#       <td id="T_070cb_row1_col1" class="data row1 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_070cb_level0_row2" class="row_heading level0 row2" >35</th>
# ...

# %% [markdown]
# ###### Findings :
#     - Number of state that acheive 100% participation rate decreased.
#     - North Dakota has low SAT participation rate was 100% because it was mandatory to take ACT in the state.

# %%
#Display states of lowest ACT participation Rate for 2017, 2018, 2019

df10 = combined_final[combined_final['act_participation_2017'] == combined_final['act_participation_2017'].min()][['state','act_participation_2017']]
df11 = combined_final[combined_final['act_participation_2018'] == combined_final['act_participation_2018'].min()][['state','act_participation_2018']]
df12 = combined_final[combined_final['act_participation_2019'] == combined_final['act_participation_2019'].min()][['state','act_participation_2019']]

df10_styler = df10.style.set_table_attributes("style='display:inline'").set_caption('Lowest ACT participation rate for 2017')
df11_styler = df11.style.set_table_attributes("style='display:inline'").set_caption('Lowest ACT participation rate for 2018')
df12_styler = df12.style.set_table_attributes("style='display:inline'").set_caption('Lowest ACT participation rate for 2019')

space = "\xa0" * 20
display_html(df10_styler._repr_html_()+ space  + df11_styler._repr_html_()+ space  + df12_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc6f3_" style='display:inline'>
#   <caption>Lowest ACT participation rate for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_participation_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc6f3_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_dc6f3_row0_col0" class="data row0 col0" >Maine</td>
#       <td id="T_dc6f3_row0_col1" class="data row0 col1" >0.080000</td>
#     </tr>
#   </tbody>
# </table>
#                     <style type="text/css">
# </style>
# <table id="T_a9a18_" style='display:inline'>
#   <caption>Lowest ACT participation rate for 2018</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
# ...

# %% [markdown]
# ###### Findings :
#     - Maine has low ACT participation rate due to mostly the student there took SAT.

# %% [markdown]
# ##### Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT and ACT?

# %%
#Display states of top 5 mean total SAT scores for 2017, 2018, 2019
df13 = combined_final.loc[:, ['state', 'sat_total_2017']].sort_values(by='sat_total_2017', ascending=False).head()
df14 = combined_final.loc[:, ['state', 'sat_total_2018']].sort_values(by='sat_total_2018', ascending=False).head()
df15 = combined_final.loc[:, ['state', 'sat_total_2019']].sort_values(by='sat_total_2019', ascending=False).head()

df13_styler = df13.style.set_table_attributes("style='display:inline'").set_caption('Top 5 SAT mean total for 2017')
df14_styler = df14.style.set_table_attributes("style='display:inline'").set_caption('Top 5 SAT mean total for 2018')
df15_styler = df15.style.set_table_attributes("style='display:inline'").set_caption('Top 5 SAT mean total for 2019')

space = "\xa0" * 20
display_html(df13_styler._repr_html_()+ space  + df14_styler._repr_html_()+ space  + df15_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_abbfb_" style='display:inline'>
#   <caption>Top 5 SAT mean total for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_total_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abbfb_level0_row0" class="row_heading level0 row0" >24</th>
#       <td id="T_abbfb_row0_col0" class="data row0 col0" >Minnesota</td>
#       <td id="T_abbfb_row0_col1" class="data row0 col1" >1295</td>
#     </tr>
#     <tr>
#       <th id="T_abbfb_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_abbfb_row1_col0" class="data row1 col0" >Wisconsin</td>
#       <td id="T_abbfb_row1_col1" class="data row1 col1" >1291</td>
#     </tr>
#     <tr>
#       <th id="T_abbfb_level0_row2" class="row_heading level0 row2" >15</th>
# ...

# %%
#Display states of top 5 mean composite ACT scores for 2017, 2018, 2019
df16 = combined_final.loc[:, ['state', 'act_composite_2017']].sort_values(by='act_composite_2017', ascending=False).head()
df17 = combined_final.loc[:, ['state', 'act_composite_2018']].sort_values(by='act_composite_2018', ascending=False).head()
df18 = combined_final.loc[:, ['state', 'act_composite_2019']].sort_values(by='act_composite_2019', ascending=False).head()

df16_styler = df16.style.set_table_attributes("style='display:inline'").set_caption('Top 5 ACT mean composite for 2017')
df17_styler = df17.style.set_table_attributes("style='display:inline'").set_caption('Top 5 ACT mean composite for 2018')
df18_styler = df18.style.set_table_attributes("style='display:inline'").set_caption('Top 5 ACT mean composite for 2019')

space = "\xa0" * 20
display_html(df16_styler._repr_html_()+ space  + df17_styler._repr_html_()+ space  + df18_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_491d1_" style='display:inline'>
#   <caption>Top 5 ACT mean composite for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_composite_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_491d1_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_491d1_row0_col0" class="data row0 col0" >New Hampshire</td>
#       <td id="T_491d1_row0_col1" class="data row0 col1" >25.500000</td>
#     </tr>
#     <tr>
#       <th id="T_491d1_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_491d1_row1_col0" class="data row1 col0" >Massachusetts</td>
#       <td id="T_491d1_row1_col1" class="data row1 col1" >25.400000</td>
#     </tr>
#     <tr>
#       <th id="T_491d1_level0_row2" class="row_heading level0 row2" >6</th>
# ...

# %%
#Display states of bottom 5 mean total SAT scores for 2017, 2018, 2019
df19 = combined_final.loc[:, ['state', 'sat_total_2017']].sort_values(by='sat_total_2017', ascending=True).head()
df20 = combined_final.loc[:, ['state', 'sat_total_2018']].sort_values(by='sat_total_2018', ascending=True).head()
df21 = combined_final.loc[:, ['state', 'sat_total_2019']].sort_values(by='sat_total_2019', ascending=True).head()

df19_styler = df19.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 SAT mean total for 2017')
df20_styler = df20.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 SAT mean total for 2018')
df21_styler = df21.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 SAT mean total for 2019')

space = "\xa0" * 20
display_html(df19_styler._repr_html_()+ space  + df20_styler._repr_html_()+ space  + df21_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c815_" style='display:inline'>
#   <caption>Bottom 5 SAT mean total for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_total_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c815_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_7c815_row0_col0" class="data row0 col0" >District of Columbia</td>
#       <td id="T_7c815_row0_col1" class="data row0 col1" >950</td>
#     </tr>
#     <tr>
#       <th id="T_7c815_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_7c815_row1_col0" class="data row1 col0" >Delaware</td>
#       <td id="T_7c815_row1_col1" class="data row1 col1" >996</td>
#     </tr>
#     <tr>
#       <th id="T_7c815_level0_row2" class="row_heading level0 row2" >12</th>
# ...

# %%
#Display states of bottom 5 mean composite ACT scores for 2017, 2018, 2019
df22 = combined_final.loc[:, ['state', 'act_composite_2017']].sort_values(by='act_composite_2017', ascending=True).head()
df23 = combined_final.loc[:, ['state', 'act_composite_2018']].sort_values(by='act_composite_2018', ascending=True).head()
df24 = combined_final.loc[:, ['state', 'act_composite_2019']].sort_values(by='act_composite_2019', ascending=True).head()

df22_styler = df22.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 ACT mean composite for 2017')
df23_styler = df23.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 ACT mean composite for 2018')
df24_styler = df24.style.set_table_attributes("style='display:inline'").set_caption('Bottom 5 ACT mean composite for 2019')

space = "\xa0" * 20
display_html(df22_styler._repr_html_()+ space  + df23_styler._repr_html_()+ space  + df24_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d809_" style='display:inline'>
#   <caption>Bottom 5 ACT mean composite for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_composite_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d809_level0_row0" class="row_heading level0 row0" >29</th>
#       <td id="T_2d809_row0_col0" class="data row0 col0" >Nevada</td>
#       <td id="T_2d809_row0_col1" class="data row0 col1" >17.800000</td>
#     </tr>
#     <tr>
#       <th id="T_2d809_level0_row1" class="row_heading level0 row1" >25</th>
#       <td id="T_2d809_row1_col0" class="data row1 col0" >Mississippi</td>
#       <td id="T_2d809_row1_col1" class="data row1 col1" >18.600000</td>
#     </tr>
#     <tr>
#       <th id="T_2d809_level0_row2" class="row_heading level0 row2" >41</th>
# ...

# %% [markdown]
# ##### Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
# Create new columns for the change in SAT year to year participation rates
combined_final['sat_diff_17_18'] = combined_final['sat_participation_2018'] - combined_final['sat_participation_2017']
combined_final['sat_diff_18_19'] = combined_final['sat_participation_2019'] - combined_final['sat_participation_2018']
# Create new columns for the change in ACT year to year participation rates
combined_final['act_diff_17_18'] = combined_final['act_participation_2018'] - combined_final['act_participation_2017']
combined_final['act_diff_18_19'] = combined_final['act_participation_2019'] - combined_final['act_participation_2018']
# Out:
# C:\Users\CADMIN~1\AppData\Local\Temp/ipykernel_11760/402343148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_final['sat_diff_17_18'] = combined_final['sat_participation_2018'] - combined_final['sat_participation_2017']
# C:\Users\CADMIN~1\AppData\Local\Temp/ipykernel_11760/402343148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_final['sat_diff_18_19'] = combined_final['sat_participation_2019'] - combined_final['sat_participation_2018']
# ...

# %%
#Display states with 100% SAT participation on a given test have a rate change year-to-year.

df25 = combined_final[(combined_final['sat_participation_2017'] == 1.0) & (combined_final['sat_diff_17_18'] != 0.0)][['state','sat_participation_2017','sat_participation_2018','sat_diff_17_18']]
df26 = combined_final[(combined_final['sat_participation_2018'] == 1.0) & (combined_final['sat_diff_18_19'] != 0.0)][['state','sat_participation_2018','sat_participation_2019','sat_diff_18_19']]

df25_styler = df25.style.set_table_attributes("style='display:inline'").set_caption('State with SAT 100% participation with changes year 17-18')
df26_styler = df26.style.set_table_attributes("style='display:inline'").set_caption('State with SAT 100% participation with changes year 18-19')

space = "\xa0" * 40
display_html(df25_styler._repr_html_()+ space  + df26_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_209bf_" style='display:inline'>
#   <caption>State with SAT 100% participation with changes year 17-18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_participation_2017</th>
#       <th class="col_heading level0 col2" >sat_participation_2018</th>
#       <th class="col_heading level0 col3" >sat_diff_17_18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_209bf_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_209bf_row0_col0" class="data row0 col0" >District of Columbia</td>
#       <td id="T_209bf_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_209bf_row0_col2" class="data row0 col2" >0.920000</td>
#       <td id="T_209bf_row0_col3" class="data row0 col3" >-0.080000</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
#Display states with 100% ACT participation on a given test have a rate change year-to-year.
df27 = combined_final[(combined_final['act_participation_2017'] == 1.0) & (combined_final['act_diff_17_18'] != 0.0)][['state','act_participation_2017','act_participation_2018','act_diff_17_18']]
df28 = combined_final[(combined_final['act_participation_2018'] == 1.0) & (combined_final['act_diff_18_19'] != 0.0)][['state','act_participation_2018','act_participation_2019','act_diff_18_19']]

df27_styler = df27.style.set_table_attributes("style='display:inline'").set_caption('State with ACT 100% participation with changes year 17-18')
df28_styler = df28.style.set_table_attributes("style='display:inline'").set_caption('State with ACT 100% participation with changes year 18-19')

space = "\xa0" * 40
display_html( df27_styler._repr_html_()+ space  + df28_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_96953_" style='display:inline'>
#   <caption>State with ACT 100% participation with changes year 17-18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_participation_2017</th>
#       <th class="col_heading level0 col2" >act_participation_2018</th>
#       <th class="col_heading level0 col3" >act_diff_17_18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96953_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_96953_row0_col0" class="data row0 col0" >Colorado</td>
#       <td id="T_96953_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_96953_row0_col2" class="data row0 col2" >0.300000</td>
#       <td id="T_96953_row0_col3" class="data row0 col3" >-0.700000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ###### Findings :
#     - Colorado made SAT as the mandatory standardize test in 2017
#     -

# %% [markdown]
# ##### Do any states show have >50% participation on both tests each year?

# %%
df29 = combined_final[(combined_final['sat_participation_2018'] >= 0.50) & (combined_final['act_participation_2018'] >= 0.50)][['state','sat_participation_2017','act_participation_2018']]
df30 = combined_final[(combined_final['sat_participation_2019'] >= 0.50) & (combined_final['act_participation_2019'] >= 0.50)][['state','sat_participation_2018','act_participation_2019']]

df29_styler = df29.style.set_table_attributes("style='display:inline'").set_caption('State with >50% participation rate on both Test in 2018')
df30_styler = df30.style.set_table_attributes("style='display:inline'").set_caption('State with >50% participation rate on both Test in 2019')

space = "\xa0" * 40
display_html( df29_styler._repr_html_()+ space  + df30_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec92b_" style='display:inline'>
#   <caption>State with >50% participation rate on both Test in 2018</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_participation_2017</th>
#       <th class="col_heading level0 col2" >act_participation_2018</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec92b_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_ec92b_row0_col0" class="data row0 col0" >Florida</td>
#       <td id="T_ec92b_row0_col1" class="data row0 col1" >0.830000</td>
#       <td id="T_ec92b_row0_col2" class="data row0 col2" >0.660000</td>
#     </tr>
#     <tr>
#       <th id="T_ec92b_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_ec92b_row1_col0" class="data row1 col0" >Georgia</td>
# ...

# %% [markdown]
# ##### What is the largest & smallest changes in participation rate for the tests between year to year?

# %%
# Get the largest & smallest changes in SAT participation
df25 = combined_final.nlargest(5,['sat_diff_17_18'])[['state','sat_participation_2017','sat_participation_2018','sat_diff_17_18']]
df26 = combined_final.nlargest(5,['sat_diff_18_19'])[['state','sat_participation_2018','sat_participation_2019','sat_diff_18_19']]
df27 = combined_final.nsmallest(5,['sat_diff_17_18'])[['state','sat_participation_2017','sat_participation_2018','sat_diff_17_18']]
df28 = combined_final.nsmallest(5,['sat_diff_18_19'])[['state','sat_participation_2018','sat_participation_2019','sat_diff_18_19']]

df25_styler = df25.style.set_table_attributes("style='display:inline'").set_caption('Top 5 largest change between SAT year 17-18')
df26_styler = df26.style.set_table_attributes("style='display:inline'").set_caption('Top 5 largest change between SAT year 18-19')
df27_styler = df27.style.set_table_attributes("style='display:inline'").set_caption('Top 5 smallest change between SAT year 17-18')
df28_styler = df28.style.set_table_attributes("style='display:inline'").set_caption('Top 5 smallest change between SAT year 18-19')


space = "\xa0" * 20
display_html(df25_styler._repr_html_()+ space  + df26_styler._repr_html_()+ space  + df27_styler._repr_html_()+ space  + df28_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c349d_" style='display:inline'>
#   <caption>Top 5 largest change between SAT year 17-18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >sat_participation_2017</th>
#       <th class="col_heading level0 col2" >sat_participation_2018</th>
#       <th class="col_heading level0 col3" >sat_diff_17_18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c349d_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_c349d_row0_col0" class="data row0 col0" >Illinois</td>
#       <td id="T_c349d_row0_col1" class="data row0 col1" >0.090000</td>
#       <td id="T_c349d_row0_col2" class="data row0 col2" >0.990000</td>
#       <td id="T_c349d_row0_col3" class="data row0 col3" >0.900000</td>
#     </tr>
#     <tr>
# ...

# %%
# Get the largest & smallest changes in ACT participation
df29 = combined_final.nlargest(5,['act_diff_17_18'])[['state','act_participation_2017','act_participation_2018','act_diff_17_18']]
df30 = combined_final.nlargest(5,['act_diff_18_19'])[['state','act_participation_2018','act_participation_2019','act_diff_18_19']]
df31 = combined_final.nsmallest(5,['act_diff_17_18'])[['state','act_participation_2017','act_participation_2018','act_diff_17_18']]
df32 = combined_final.nsmallest(5,['act_diff_18_19'])[['state','act_participation_2018','act_participation_2019','act_diff_18_19']]

df29_styler = df29.style.set_table_attributes("style='display:inline'").set_caption('Top 5 largest change between ACT year 17-18')
df30_styler = df30.style.set_table_attributes("style='display:inline'").set_caption('Top 5 largest change between ACT year 18-19')
df31_styler = df31.style.set_table_attributes("style='display:inline'").set_caption('Top 5 smallest change between ACT year 17-18')
df32_styler = df32.style.set_table_attributes("style='display:inline'").set_caption('Top 5 smallest change between ACT year 18-19')


space = "\xa0" * 20
display_html(df29_styler._repr_html_()+ space  + df30_styler._repr_html_()+ space  + df31_styler._repr_html_()+ space  + df32_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b978_" style='display:inline'>
#   <caption>Top 5 largest change between ACT year 17-18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_participation_2017</th>
#       <th class="col_heading level0 col2" >act_participation_2018</th>
#       <th class="col_heading level0 col3" >act_diff_17_18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b978_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_0b978_row0_col0" class="data row0 col0" >Ohio</td>
#       <td id="T_0b978_row0_col1" class="data row0 col1" >0.750000</td>
#       <td id="T_0b978_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_0b978_row0_col3" class="data row0 col3" >0.250000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### Shortlisting

# %%
#Shortlist the state to focus on putting more resouces and efforts
combined_final[
    (combined_final['sat_total_2019'] >= 1200) & 
    (combined_final['act_participation_2018'] >= 0.00)][
                   ['state','sat_participation_2019',
                    'act_participation_2019',
                    'sat_total_2019']].sort_values(
                                        by='sat_total_2019', ascending=False)
# Out:
#            state  sat_participation_2019  act_participation_2019  \
# 24     Minnesota                    0.04                    0.95
# 50     Wisconsin                    0.03                    1.00
# 42  South Dakota                    0.03                    0.75
# 35  North Dakota                    0.02                    0.96
# 28      Nebraska                    0.03                    1.00
# 15          Iowa                    0.03                    0.66
# 16        Kansas                    0.04                    0.72
# 51       Wyoming                    0.03                    1.00
# 25   Mississippi                    0.03                    1.00
# 26      Missouri                    0.04                    0.82
# 17      Kentucky                    0.04                    1.00
# 45          Utah                    0.04                    1.00
# 43     Tennessee                    0.07                    1.00
# ...

# %%
combined_final.loc[:, ['state', 'sat_participation_2019','act_participation_2019','sat_total_2019','act_composite_2019']].sort_values(by=['sat_total_2019','act_participation_2019'], ascending=[False,True]).head(5)
# Out:
#            state  sat_participation_2019  act_participation_2019  \
# 24     Minnesota                    0.04                    0.95
# 50     Wisconsin                    0.03                    1.00
# 42  South Dakota                    0.03                    0.75
# 35  North Dakota                    0.02                    0.96
# 28      Nebraska                    0.03                    1.00
#
#     sat_total_2019  act_composite_2019
# 24            1284                21.4
# 50            1283                20.3
# 42            1268                21.6
# 35            1263                19.9
# 28            1260                20.0

# %%
#Display states of highest ACT participation Rate for 2017, 2018, 2019

df4 = combined_final[combined_final['act_participation_2017'] == combined_final['act_participation_2017'].max()][['state','act_participation_2017']]
df5 = combined_final[combined_final['act_participation_2018'] == combined_final['act_participation_2018'].max()][['state','act_participation_2018']]
df6 = combined_final[combined_final['act_participation_2019'] == combined_final['act_participation_2019'].max()][['state','act_participation_2019']]

df4_styler = df4.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2017')
df5_styler = df5.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2018')
df6_styler = df6.style.set_table_attributes("style='display:inline'").set_caption('Highest ACT participation rate for 2019')

space = "\xa0" * 20
display_html(df4_styler._repr_html_()+ space  + df5_styler._repr_html_()+ space  + df6_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e034a_" style='display:inline'>
#   <caption>Highest ACT participation rate for 2017</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >act_participation_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e034a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e034a_row0_col0" class="data row0 col0" >Alabama</td>
#       <td id="T_e034a_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e034a_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_e034a_row1_col0" class="data row1 col0" >Arkansas</td>
#       <td id="T_e034a_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e034a_level0_row2" class="row_heading level0 row2" >5</th>
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# set size of plot
plt.figure(figsize=(14, 12))

# add title to plot
plt.title("Correlation between SAT & ACT data for 2017, 2018 & 2019", fontsize = 24)

# creating mask
mask = np.triu(np.ones_like(combined_final.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(combined_final.corr(), cmap="coolwarm", annot=True, mask=mask)
 
# displaying heatmap
plt.show()

# %% [markdown]
# ##### Findings :
#     - ACT Participation Rate vs SAT Participation Rate are inverse correlation, between two variables, indicates that one variable increases while the other decreases, and vice-versa.
#     - SAT Total Score

# %%
# Function for creating subplot
plt.style.use('bmh')
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels,figtitle):
    nrows = int(np.ceil(len(list_of_columns)/3)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(25,15), sharey=True) # You'll want to specify your fig size
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    fig.suptitle(figtitle, size=16) #set fig title
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],edgecolor='black', linewidth=2) # feel free to add more settings
        ax[i].set_title(list_of_titles[i],fontsize = 16) # Set titles for each subplot
        ax[i].set_xlabel(list_of_xlabels[i],fontsize = 12) # Set xlabels for each subplot
        ax[i].axvline(np.median(dataframe[column]), color='red',label = 'Median'  ,linestyle='dashed', linewidth=1)
        ax[i].legend()

# %%
# generating subplot 
subplot_histograms(combined_final, 
                   list_of_columns=['sat_participation_2017','sat_participation_2018','sat_participation_2019',
                                   'act_participation_2017','act_participation_2018','act_participation_2019'], 
                   list_of_titles=['SAT 2017 Participation','SAT 2018 Participation','SAT 2019 Participation',
                                   'ACT 2017 Participation','ACT 2018 Participation','ACT 2019 Participation'], 
                   list_of_xlabels=['Participation Rate','Participation Rate','Participation Rate',
                                    'Participation Rate','Participation Rate','Participation Rate'],
                   figtitle = 'SAT & ACT Participation Rate'
                   )

# %% [markdown]
# ##### Findings
# 1. The two standardized test distrubution of the same year are almost mirrored.
#     - Meaning that the higher the participation rate of either test, the lower the partication rate of the other test.
#     - This is possibly because highly chance that students are not taking both SAT and ACT test.

# %%
plt.subplots(figsize=(26, 10))
plt.subplot(231)
plt.title('SAT & ACT 2017, 2018 & 2019 Participation Rates')
xticklabels = ['SAT 17', 'SAT 18', 'SAT 19', 'ACT 17','ACT 18','ACT 19']
sns.boxplot(data=combined_final[['sat_participation_2017', 'sat_participation_2018', 
                                 'sat_participation_2019','act_participation_2017',
                                 'act_participation_2018','act_participation_2019'
                                  ]]).set_xticklabels(xticklabels)

plt.subplot(232)
plt.ylim(800, 1400)
plt.title('SAT Total Score 2017, 2018 & 2019')
xticklabels = ['SAT 2017 totals', 'SAT 2018 totals', 'SAT 2019 totals']
sns.boxplot(data=combined_final[['sat_total_2017', 'sat_total_2018','sat_total_2019']]).set_xticklabels(xticklabels)


plt.subplot(233)
plt.ylim(12, 36)
plt.title('ACT Composite Scores 2017, 2018 & 2019')
xticklabels = ['ACT 2017 totals', 'ACT 2018 totals', 'ACT 2019 totals']
sns.boxplot(data=combined_final[['act_composite_2017', 'act_composite_2018','act_composite_2019']]).set_xticklabels(xticklabels);

# %% [markdown]
# ##### Findings
# 1. SAT Participation Rate is growing throughout the 3 years while ACT Participation Rate starts to declined.
# 2. The scoring are quite centrally distrubuted throughout the years.
#     - Majority of the students take SAT score between 1038 to 1212
#     - Majority of the students take ACT score between 19.8 to 23.7
#     - Base on the ACT to SAT Score Conversion Chart, it seem that the 75th percentile of the SAT score grade is 1 pointer better then ACT.

# %%
def subplot_scatter(dataframe, list_of_xcolumns, list_of_ycolumns, list_of_titles, list_of_xlabels, list_of_ylabels, figtitle ):
    if len(list_of_xcolumns)%3 == 0:
            nrows = int(np.ceil(len(list_of_xcolumns)/3))
            fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(16, 5*nrows)) # You'll want to specify your figsize
    else:
            nrows = int(np.ceil(len(list_of_xcolumns)/2)) # Makes sure you have enough rows
            fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(16, 5*nrows)) # You'll want to specify your figsize
    ax = ax.ravel()
    fig.suptitle(figtitle, size=16) #set fig title
    for i, column in enumerate(list_of_xcolumns):
        ax[i].scatter(dataframe[column], dataframe[list_of_ycolumns[i]])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])
        ax[i].plot([0,1],[0,1], transform=ax[i].transAxes, color='red', linestyle='dashed', linewidth=1)

# %%
xcolumns = ['sat_total_2017', 'sat_total_2018','act_composite_2017','act_composite_2018']
ycolumns = ['sat_total_2018', 'sat_total_2019','act_composite_2018','act_composite_2019']
titles = ['SAT Total 2017 vs 2018', 'SAT Total 2018 vs 2019', 'ACT Composite 2017 vs 2018','ACT Composite 2018 vs 2019']
xlabels = ['SAT 2017 Total', 'SAT 2018 Total', 'ACT 2017 Composite','ACT 2018 Composite']
ylabels = ['SAT 2018 Total', 'SAT 2019 Total', 'ACT 2018 Composite','ACT 2019 Composite']
figtitle = 'Scatter Plot Graphs - Scores relation between the following years'
subplot_scatter(combined_final, xcolumns, ycolumns, titles, xlabels, ylabels,figtitle)

# %% [markdown]
# ##### Findings
# 1. There is a distinct positive correlation between the scores of the same standardized tests against the next year.
#     - Meaning that the majority batch of the students taking the test are likely to get around the same range of scores.

# %%
xcolumns = ['sat_participation_2017', 'sat_participation_2018','sat_participation_2019',
            'act_participation_2017','act_participation_2018','act_participation_2019']

ycolumns = ['sat_total_2017', 'sat_total_2018' , 'sat_total_2019',
            'act_composite_2017','act_composite_2018','act_composite_2019']

titles = ['SAT Participation Rate vs Total Score 2017', 'SAT Participation Rate vs Total Score 2018', 'SAT Participation Rate vs Total Score 2019',
          'ACT Participation Rate vs Composite Score 2017','ACT Participation Rate vs Composite Score 2018','ACT Participation Rate vs Composite Score 2019']

xlabels = ['SAT Participation Rate 2017', 'SAT Participation Rate 2018', 'SAT Participation Rate 2019',
           'ACT Participation Rate 2017','ACT Participation Rate 2018','ACT Participation Rate 2019']

ylabels = ['SAT 2017 Total', 'SAT 2018 Total', 'SAT 2019 Total',
           'ACT 2017 Composite','ACT 2018 Composite','ACT 2019 Composite']
figtitle = 'Scatter Plot Graphs - relations between scores and participation rate'
subplot_scatter(combined_final, xcolumns, ycolumns, titles, xlabels, ylabels,figtitle)

# %% [markdown]
# ##### Findings
# 1. There is a distinct negative correlation between participation rates and test scores of the same year.
#     - Meaning that the higher the participation rate the higher the rate of lower score acheived by the students.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
#
# ### Conclusion:
# 1. SAT and ACT test scores are inversely related to their test participation rates, the higher the participation rates the higher the number of score registered is lower.
# 2. SAT and ACT participation rates are inversely related to each other, which shows that most students tend to take only one or the other test.
# 3. The SAT scoring between the year are positively correlation, which means that there would not have major fluctuation of the scoring in the different years.
# 4. From consulting outside sources as to the reasons for the two biggest increases in SAT participation rates, a common factor of cost savings was found between the 3 states which most recently decided to switch from ACT to SAT.
# 5. Participation in such tests is heavily influenced by state policy towards testing.
#
#
# ### Recommendation
# 6. Based on the 2019 SAT Scores by Intended College Major, the student SAT scoring above 1203 would like to apply for 97.36% of the major.
# 7. We shortlist the state that student has the mean total score of above 1200.
# 8. We further bring down the states shortlisted to four:
#    - Minnesota
#    - Tenneessee
#    - Kansas
#    - Missouri
#    basing on these four state have good ACT participation rate (inversely related to lower SAT participation rate) and the current state policy open to both SAT and ACT test.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
